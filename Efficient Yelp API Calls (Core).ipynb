# %% [markdown]
# # Efficient Yelp API Calls

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time
from tqdm.notebook import tqdm_notebook
from yelpapi import YelpAPI

# %% [markdown]
# ### Load Credentials and Create Yelp API Object

# %%
# Load API Credentials
with open('C:/Users/paulm/.secret/yelp_api.json', 'r') as f:
    login = json.load(f)

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['api-key'], timeout_s = 5.0)

# %% [markdown]
# ### Define Search Terms and File Paths

# %%
# Setting location and term
location = 'Austin, TX 78758'
term = 'ramen'

# %%
location.split(',')[0]
# Out:
# 'Austin'

# %%
## Specify fodler for saving data
FOLDER = 'Data/'

os.makedirs(FOLDER, exist_ok = True)
# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
JSON_FILE
# Out:
# 'Data/Austin-ramen.json'

# %% [markdown]
# ### Check if Json File exists and Create it if it doesn't

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exists == False:    
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder, exist_ok = True)
            
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE, 'w') as f:
        json.dump([], f)
        
## If it exists, inform user
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Austin-ramen.json already exists.

# %%
# use our yelp_api variable's search_query method to perform our API call
results = yelp.search_query(term = term, location = location,
                           offset =20)

# %%
## How many results total?
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 122

# %%
results['region']
# Out:
# {'center': {'longitude': -97.70965576171875, 'latitude': 30.384120147645305}}

# %%
results['businesses']
# Out:
# [{'id': 'kEma28uCu8POf0MWE8ED1w',
#   'alias': 'ebisu-japanese-restaurant-austin',
#   'name': 'Ebisu Japanese Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RxsjI3mNE5maYAQ5AJb05w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ebisu-japanese-restaurant-austin?adjust_creative=SII3Zx0pocTC_aRxodkG1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SII3Zx0pocTC_aRxodkG1A',
#   'review_count': 374,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.444849, 'longitude': -97.788883},
#   'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '13376 N Hwy 183',
#    'address2': 'Ste 400',
#    'address3': '',
#    'city': 'Austin',
#    'zip_code': '78750',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['13376 N Hwy 183', 'Ste 400', 'Austin, TX 78750']},
#   'phone': '+15122435554',
#   'display_phone': '(512) 243-5554',
#   'distance': 10164.58046384204},
#  {'id': 'Q7mYMmlbhOWUIo6R6hy7qw',
#   'alias': 'julies-noodles-austin',
#   'name': "Julie's Noodles",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PFUTXue9KCIWoM9awbKj4Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/julies-noodles-austin?adjust_creative=SII3Zx0pocTC_aRxodkG1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SII3Zx0pocTC_aRxodkG1A',
#   'review_count': 593,
#   'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.3611406172422,
#    'longitude': -97.7157957205178},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '8557 Research Blvd',
#    'address2': 'Ste 110',
#    'address3': None,
#    'city': 'Austin',
#    'zip_code': '78758',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['8557 Research Blvd', 'Ste 110', 'Austin, TX 78758']},
#   'phone': '+15123946967',
#   'display_phone': '(512) 394-6967',
#   'distance': 2622.2177521419867},
#  {'id': 'ihF6S9W0nZNwI3GGXseU9Q',
#   'alias': 'goya-austin-9',
#   'name': 'Goya',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/I5suvyo1ElBR0DgFiVqGTA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/goya-austin-9?adjust_creative=SII3Zx0pocTC_aRxodkG1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SII3Zx0pocTC_aRxodkG1A',
#   'review_count': 170,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.4609, 'longitude': -97.79467},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '13776 US N 183 Hwy',
#    'address2': 'Ste 134',
#    'address3': '',
#    'city': 'Austin',
#    'zip_code': '78750',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['13776 US N 183 Hwy', 'Ste 134', 'Austin, TX 78750']},
#   'phone': '+15128140130',
#   'display_phone': '(512) 814-0130',
#   'distance': 11162.41139594004},
#  {'id': 'dy0qBvJS4UshKzziC3fwRA',
#   'alias': 'soto-japanese-restaurant-and-sushi-bar-cedar-park-3',
#   'name': 'Soto Japanese Restaurant & Sushi Bar',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/elZhHAgVRIX5XbfU8A5Hhw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/soto-japanese-restaurant-and-sushi-bar-cedar-park-3?adjust_creative=SII3Zx0pocTC_aRxodkG1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SII3Zx0pocTC_aRxodkG1A',
#   'review_count': 1022,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.470254940882956,
#    'longitude': -97.80104873896101},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '11066 Pecan Park Blvd',
#    'address2': 'Ste 402',
#    'address3': '',
#    'city': 'Cedar Park',
#    'zip_code': '78613',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['11066 Pecan Park Blvd',
#     'Ste 402',
#     'Cedar Park, TX 78613']},
#   'phone': '+15122570788',
#   'display_phone': '(512) 257-0788',
#   'distance': 12981.508373588566},
#  {'id': 'gJAWFZi1pqnGNXx_20xdMg',
#   'alias': 'hotpot-alley-austin-2',
#   'name': 'Hotpot Alley',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/r3sHkWY5VKTwHfC3dJ9enA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hotpot-alley-austin-2?adjust_creative=SII3Zx0pocTC_aRxodkG1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SII3Zx0pocTC_aRxodkG1A',
#   'review_count': 76,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'hotpot', 'title': 'Hot Pot'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.46724938131647,
#    'longitude': -97.79465884373553},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '13201 Ranch Rd 620 N',
#    'address2': 'Ste U 208',
#    'address3': None,
#    'city': 'Austin',
#    'zip_code': '78717',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['13201 Ranch Rd 620 N',
#     'Ste U 208',
#     'Austin, TX 78717']},
#   'phone': '+15128529288',
#   'display_phone': '(512) 852-9288',
#   'distance': 12323.535969605544},
#  {'id': 'QVVoIHWggdCxZuZQjllD_Q',
#   'alias': 'midori-sushi-austin',
#   'name': 'Midori Sushi',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GdEXKIFNnPRfEw3N6xDgEw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/midori-sushi-austin?adjust_creative=SII3Zx0pocTC_aRxodkG1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SII3Zx0pocTC_aRxodkG1A',
#   'review_count': 986,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.448741292198, 'longitude': -97.7877103232788},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '13435 N Hwy 183',
#    'address2': 'Ste 301',
#    'address3': '',
#    'city': 'Austin',
#    'zip_code': '78750',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['13435 N Hwy 183', 'Ste 301', 'Austin, TX 78750']},
#   'phone': '+15122571411',
#   'display_phone': '(512) 257-1411',
#   'distance': 10375.594860643281},
#  {'id': 'kCay_3uqhE44jaWNDCBmhA',
#   'alias': 'thai-kun-austin-2',
#   'name': 'Thai Kun',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2qYa4iTsr1UoOKbUEjUrZw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/thai-kun-austin-2?adjust_creative=SII3Zx0pocTC_aRxodkG1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SII3Zx0pocTC_aRxodkG1A',
#   'review_count': 619,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.4016022028548,
#    'longitude': -97.7223529556808},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '11601 Rock Rose Ave',
#    'address2': 'Ste 100',
#    'address3': '',
#    'city': 'Austin',
#    'zip_code': '78758',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['11601 Rock Rose Ave', 'Ste 100', 'Austin, TX 78758']},
#   'phone': '+15123945550',
#   'display_phone': '(512) 394-5550',
#   'distance': 2293.8903413119447},
#  {'id': 'WstMx2Utm7-fFtWvlMXrNA',
#   'alias': 'joi-austin',
#   'name': 'Joi',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/N2CpHsT0UrWGNa5WKx1HTg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joi-austin?adjust_creative=SII3Zx0pocTC_aRxodkG1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SII3Zx0pocTC_aRxodkG1A',
#   'review_count': 170,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 30.40301526685455,
#    'longitude': -97.72161307423309},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '3120 Palm Way',
#    'address2': 'Ste 150',
#    'address3': None,
#    'city': 'Austin',
#    'zip_code': '78758',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['3120 Palm Way', 'Ste 150', 'Austin, TX 78758']},
#   'phone': '+15126151070',
#   'display_phone': '(512) 615-1070',
#   'distance': 2393.6722061610058},
#  {'id': 'Bz-NZ-2Dx6pztO0nvfD3JA',
#   'alias': 'nori-austin',
#   'name': 'Nori',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jUkG4I7moa6isCFCxi2Lww/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nori-austin?adjust_creative=SII3Zx0pocTC_aRxodkG1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SII3Zx0pocTC_aRxodkG1A',
#   'review_count': 104,
#   'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.2999, 'longitude': -97.74031},
#   'transactions': [],
#   'location': {'address1': '3208 Guadalupe St',
#    'address2': 'Ste B',
#    'address3': None,
#    'city': 'Austin',
#    'zip_code': '78705',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['3208 Guadalupe St', 'Ste B', 'Austin, TX 78705']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 9809.83291878434},
#  {'id': 'FpzMEfjhCm8Y9JjaTx5X5g',
#   'alias': 'pho-dan-austin-3',
#   'name': 'Pho Dan',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gnLfJsBZopfsq5fIc-xHdA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pho-dan-austin-3?adjust_creative=SII3Zx0pocTC_aRxodkG1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SII3Zx0pocTC_aRxodkG1A',
#   'review_count': 499,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.382055738338, 'longitude': -97.687512756414},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '11220 N Lamar Blvd',
#    'address2': 'Ste 200',
#    'address3': '',
#    'city': 'Austin',
#    'zip_code': '78753',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['11220 N Lamar Blvd', 'Ste 200', 'Austin, TX 78753']},
#   'phone': '+15128377800',
#   'display_phone': '(512) 837-7800',
#   'distance': 2136.4058985496913},
#  {'id': 'v2al6SaSG25XMg4QqQQvpg',
#   'alias': 'happy-pocha-austin',
#   'name': 'Happy Pocha',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WLqmD0Fh4p3ESJChZGnlDA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/happy-pocha-austin?adjust_creative=SII3Zx0pocTC_aRxodkG1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SII3Zx0pocTC_aRxodkG1A',
#   'review_count': 93,
#   'categories': [{'alias': 'korean', 'title': 'Korean'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 30.36106951490272, 'longitude': -97.698748},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '9200 N Lamar St',
#    'address2': 'Ste 101',
#    'address3': '',
#    'city': 'Austin',
#    'zip_code': '78754',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['9200 N Lamar St', 'Ste 101', 'Austin, TX 78754']},
#   'phone': '+15128213388',
#   'display_phone': '(512) 821-3388',
#   'distance': 2768.4905911967207},
#  {'id': 'vzSXdDYtnm_F_x1hY2UVVw',
#   'alias': 'chens-noodle-house-austin',
#   'name': "Chen's Noodle House",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p-92uyi55hRnSNH7fnqjiA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chens-noodle-house-austin?adjust_creative=SII3Zx0pocTC_aRxodkG1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SII3Zx0pocTC_aRxodkG1A',
#   'review_count': 537,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.43327, 'longitude': -97.77172},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '8650 Spicewood Springs Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'Austin',
#    'zip_code': '78759',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['8650 Spicewood Springs Rd', 'Austin, TX 78759']},
#   'phone': '+15123368889',
#   'display_phone': '(512) 336-8889',
#   'distance': 7965.3337955342495},
#  {'id': '4sfF1paqVfXvzAIdzs6MQg',
#   'alias': 'uchiko-austin',
#   'name': 'Uchiko',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ja2MCM7BrxgWJP5x0GO9SA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/uchiko-austin?adjust_creative=SII3Zx0pocTC_aRxodkG1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SII3Zx0pocTC_aRxodkG1A',
#   'review_count': 2121,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.31067, 'longitude': -97.74},
#   'transactions': ['delivery'],
#   'price': '$$$$',
#   'location': {'address1': '4200 N Lamar Blvd',
#    'address2': 'Ste 140',
#    'address3': '',
#    'city': 'Austin',
#    'zip_code': '78756',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['4200 N Lamar Blvd', 'Ste 140', 'Austin, TX 78756']},
#   'phone': '+15129164808',
#   'display_phone': '(512) 916-4808',
#   'distance': 8669.283179196875},
#  {'id': 'Qt6EKCL-6p414rLRpTK4MA',
#   'alias': 'o-daku-sushi-austin',
#   'name': "O'daku Sushi",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RxHs0PJUcgoA4Ur-ZH0jyA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/o-daku-sushi-austin?adjust_creative=SII3Zx0pocTC_aRxodkG1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SII3Zx0pocTC_aRxodkG1A',
#   'review_count': 258,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'korean', 'title': 'Korean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.4180224748019,
#    'longitude': -97.7023231784821},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '2501 W Parmer Ln',
#    'address2': 'Ste 500',
#    'address3': '',
#    'city': 'Austin',
#    'zip_code': '78727',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2501 W Parmer Ln', 'Ste 500', 'Austin, TX 78727']},
#   'phone': '+15128349304',
#   'display_phone': '(512) 834-9304',
#   'distance': 3834.7952478918833},
#  {'id': 'aUWloSmN8BcPhrp_FUY_Tw',
#   'alias': 'basil-thai-austin-4',
#   'name': 'Basil Thai',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WG3rn_ZKgiBL3zP9p2u3EA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/basil-thai-austin-4?adjust_creative=SII3Zx0pocTC_aRxodkG1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SII3Zx0pocTC_aRxodkG1A',
#   'review_count': 281,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'hotpot', 'title': 'Hot Pot'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.41815, 'longitude': -97.70212},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2501 W Parmer Ln',
#    'address2': 'Ste 550',
#    'address3': None,
#    'city': 'Austin',
#    'zip_code': '78727',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2501 W Parmer Ln', 'Ste 550', 'Austin, TX 78727']},
#   'phone': '+15125995372',
#   'display_phone': '(512) 599-5372',
#   'distance': 3754.641660965279},
#  {'id': 'A3K4Uk9l5dB5XV6f4J6fAA',
#   'alias': 'le-bleu-austin',
#   'name': 'Le Bleu',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ED-sqSmkQ9atxTEF0ehYVg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/le-bleu-austin?adjust_creative=SII3Zx0pocTC_aRxodkG1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SII3Zx0pocTC_aRxodkG1A',
#   'review_count': 242,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.372020678526145,
#    'longitude': -97.7273147705522},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '9070 Research Blvd',
#    'address2': 'Ste 303',
#    'address3': '',
#    'city': 'Austin',
#    'zip_code': '78758',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['9070 Research Blvd', 'Ste 303', 'Austin, TX 78758']},
#   'phone': '+15127701100',
#   'display_phone': '(512) 770-1100',
#   'distance': 2163.2714941206177},
#  {'id': 'KYr5xhJZ4_7Dzm1wIrW__w',
#   'alias': 'the-peached-tortilla-austin-3',
#   'name': 'The Peached Tortilla',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/b6nk8yaRfItkG4c2sk4Izw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-peached-tortilla-austin-3?adjust_creative=SII3Zx0pocTC_aRxodkG1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SII3Zx0pocTC_aRxodkG1A',
#   'review_count': 994,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'southern', 'title': 'Southern'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.33075, 'longitude': -97.74021},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '5520 Burnet Rd',
#    'address2': 'Ste 100',
#    'address3': '',
#    'city': 'Austin',
#    'zip_code': '78756',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['5520 Burnet Rd', 'Ste 100', 'Austin, TX 78756']},
#   'phone': '+15123304439',
#   'display_phone': '(512) 330-4439',
#   'distance': 6613.343656741049},
#  {'id': 'H6TRTjlEy1_GWlcOuZzbHA',
#   'alias': 'birria-queen-austin-6',
#   'name': 'Birria Queen ',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uyFtGqC4SuR-tX7Kwx1B4Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/birria-queen-austin-6?adjust_creative=SII3Zx0pocTC_aRxodkG1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SII3Zx0pocTC_aRxodkG1A',
#   'review_count': 23,
#   'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.357255, 'longitude': -97.715117},
#   'transactions': [],
#   'location': {'address1': '8339 Research Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'Austin',
#    'zip_code': '78758',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['8339 Research Blvd', 'Austin, TX 78758']},
#   'phone': '+15123586994',
#   'display_phone': '(512) 358-6994',
#   'distance': 3041.311715236946},
#  {'id': '8WJmOq0K_AEc4Ey5UcfcDw',
#   'alias': 'jan-chi-korean-cuisine-and-bbq-austin-2',
#   'name': 'Jan Chi Korean Cuisine & BBQ',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/n5Qrf4seyiHb5k1lKsEE_A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jan-chi-korean-cuisine-and-bbq-austin-2?adjust_creative=SII3Zx0pocTC_aRxodkG1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SII3Zx0pocTC_aRxodkG1A',
#   'review_count': 135,
#   'categories': [{'alias': 'korean', 'title': 'Korean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.365026831635483,
#    'longitude': -97.74901642571427},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '3808 Spicewood Springs Rd',
#    'address2': 'Ste 104',
#    'address3': None,
#    'city': 'Austin',
#    'zip_code': '78759',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['3808 Spicewood Springs Rd',
#     'Ste 104',
#     'Austin, TX 78759']},
#   'phone': '+15128529990',
#   'display_phone': '(512) 852-9990',
#   'distance': 4331.885826158507},
#  {'id': 'XH2y4duYEvKsDqIq8-WDlw',
#   'alias': 'bun-belly-austin',
#   'name': 'Bun Belly',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MGjyEOXabxsK4X13dOdUYg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bun-belly-austin?adjust_creative=SII3Zx0pocTC_aRxodkG1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SII3Zx0pocTC_aRxodkG1A',
#   'review_count': 576,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.337163276287555,
#    'longitude': -97.71672222134018},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '6929 Airport Blvd',
#    'address2': 'Ste 132',
#    'address3': '',
#    'city': 'Austin',
#    'zip_code': '78752',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['6929 Airport Blvd', 'Ste 132', 'Austin, TX 78752']},
#   'phone': '+15123584101',
#   'display_phone': '(512) 358-4101',
#   'distance': 5265.195135031215}]

# %%
## How many results total?
pd.DataFrame(results['businesses'])
# Out:
#                         id                                              alias  \
# 0   kEma28uCu8POf0MWE8ED1w                   ebisu-japanese-restaurant-austin
# 1   Q7mYMmlbhOWUIo6R6hy7qw                              julies-noodles-austin
# 2   ihF6S9W0nZNwI3GGXseU9Q                                      goya-austin-9
# 3   dy0qBvJS4UshKzziC3fwRA  soto-japanese-restaurant-and-sushi-bar-cedar-p...
# 4   gJAWFZi1pqnGNXx_20xdMg                              hotpot-alley-austin-2
# 5   QVVoIHWggdCxZuZQjllD_Q                                midori-sushi-austin
# 6   kCay_3uqhE44jaWNDCBmhA                                  thai-kun-austin-2
# 7   WstMx2Utm7-fFtWvlMXrNA                                         joi-austin
# 8   Bz-NZ-2Dx6pztO0nvfD3JA                                        nori-austin
# 9   FpzMEfjhCm8Y9JjaTx5X5g                                   pho-dan-austin-3
# 10  v2al6SaSG25XMg4QqQQvpg                                 happy-pocha-austin
# 11  vzSXdDYtnm_F_x1hY2UVVw                          chens-noodle-house-austin
# 12  4sfF1paqVfXvzAIdzs6MQg                                      uchiko-austin
# 13  Qt6EKCL-6p414rLRpTK4MA                                o-daku-sushi-austin
# 14  aUWloSmN8BcPhrp_FUY_Tw                                basil-thai-austin-4
# 15  A3K4Uk9l5dB5XV6f4J6fAA                                     le-bleu-austin
# 16  KYr5xhJZ4_7Dzm1wIrW__w                      the-peached-tortilla-austin-3
# 17  H6TRTjlEy1_GWlcOuZzbHA                              birria-queen-austin-6
# 18  8WJmOq0K_AEc4Ey5UcfcDw            jan-chi-korean-cuisine-and-bbq-austin-2
# 19  XH2y4duYEvKsDqIq8-WDlw                                   bun-belly-austin
#
#                                     name  \
# 0              Ebisu Japanese Restaurant
# 1                        Julie's Noodles
# 2                                   Goya
# 3   Soto Japanese Restaurant & Sushi Bar
# 4                           Hotpot Alley
# 5                           Midori Sushi
# 6                               Thai Kun
# 7                                    Joi
# 8                                   Nori
# 9                                Pho Dan
# 10                           Happy Pocha
# 11                   Chen's Noodle House
# 12                                Uchiko
# 13                          O'daku Sushi
# 14                            Basil Thai
# 15                               Le Bleu
# 16                  The Peached Tortilla
# 17                         Birria Queen
# 18          Jan Chi Korean Cuisine & BBQ
# 19                             Bun Belly
#
#                                             image_url  is_closed  \
# 0   https://s3-media2.fl.yelpcdn.com/bphoto/RxsjI3...      False
# 1   https://s3-media3.fl.yelpcdn.com/bphoto/PFUTXu...      False
# 2   https://s3-media3.fl.yelpcdn.com/bphoto/I5suvy...      False
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/elZhHA...      False
# 4   https://s3-media4.fl.yelpcdn.com/bphoto/r3sHkW...      False
# 5   https://s3-media2.fl.yelpcdn.com/bphoto/GdEXKI...      False
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/2qYa4i...      False
# 7   https://s3-media3.fl.yelpcdn.com/bphoto/N2CpHs...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/jUkG4I...      False
# 9   https://s3-media4.fl.yelpcdn.com/bphoto/gnLfJs...      False
# 10  https://s3-media3.fl.yelpcdn.com/bphoto/WLqmD0...      False
# 11  https://s3-media1.fl.yelpcdn.com/bphoto/p-92uy...      False
# 12  https://s3-media2.fl.yelpcdn.com/bphoto/Ja2MCM...      False
# 13  https://s3-media4.fl.yelpcdn.com/bphoto/RxHs0P...      False
# 14  https://s3-media2.fl.yelpcdn.com/bphoto/WG3rn_...      False
# 15  https://s3-media1.fl.yelpcdn.com/bphoto/ED-sqS...      False
# 16  https://s3-media4.fl.yelpcdn.com/bphoto/b6nk8y...      False
# 17  https://s3-media4.fl.yelpcdn.com/bphoto/uyFtGq...      False
# 18  https://s3-media1.fl.yelpcdn.com/bphoto/n5Qrf4...      False
# 19  https://s3-media2.fl.yelpcdn.com/bphoto/MGjyEO...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/ebisu-japanese-restau...           374
# 1   https://www.yelp.com/biz/julies-noodles-austin...           593
# 2   https://www.yelp.com/biz/goya-austin-9?adjust_...           170
# 3   https://www.yelp.com/biz/soto-japanese-restaur...          1022
# 4   https://www.yelp.com/biz/hotpot-alley-austin-2...            76
# 5   https://www.yelp.com/biz/midori-sushi-austin?a...           986
# 6   https://www.yelp.com/biz/thai-kun-austin-2?adj...           619
# 7   https://www.yelp.com/biz/joi-austin?adjust_cre...           170
# 8   https://www.yelp.com/biz/nori-austin?adjust_cr...           104
# 9   https://www.yelp.com/biz/pho-dan-austin-3?adju...           499
# 10  https://www.yelp.com/biz/happy-pocha-austin?ad...            93
# 11  https://www.yelp.com/biz/chens-noodle-house-au...           537
# 12  https://www.yelp.com/biz/uchiko-austin?adjust_...          2121
# 13  https://www.yelp.com/biz/o-daku-sushi-austin?a...           258
# 14  https://www.yelp.com/biz/basil-thai-austin-4?a...           281
# 15  https://www.yelp.com/biz/le-bleu-austin?adjust...           242
# 16  https://www.yelp.com/biz/the-peached-tortilla-...           994
# 17  https://www.yelp.com/biz/birria-queen-austin-6...            23
# 18  https://www.yelp.com/biz/jan-chi-korean-cuisin...           135
# 19  https://www.yelp.com/biz/bun-belly-austin?adju...           576
#
#                                            categories  rating  \
# 0   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 1   [{'alias': 'noodles', 'title': 'Noodles'}, {'a...     4.0
# 2   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 3   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 4   [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     4.0
# 5   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 6                [{'alias': 'thai', 'title': 'Thai'}]     4.0
# 7   [{'alias': 'asianfusion', 'title': 'Asian Fusi...     3.5
# 8   [{'alias': 'vegan', 'title': 'Vegan'}, {'alias...     4.5
# 9    [{'alias': 'vietnamese', 'title': 'Vietnamese'}]     4.0
# 10           [{'alias': 'korean', 'title': 'Korean'}]     3.5
# 11  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     4.0
# 12  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 13  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 14  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.0
# 15  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.5
# 16  [{'alias': 'asianfusion', 'title': 'Asian Fusi...     4.0
# 17             [{'alias': 'tacos', 'title': 'Tacos'}]     4.5
# 18           [{'alias': 'korean', 'title': 'Korean'}]     4.0
# 19  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.0
#
#                                           coordinates  \
# 0    {'latitude': 30.444849, 'longitude': -97.788883}
# 1   {'latitude': 30.3611406172422, 'longitude': -9...
# 2       {'latitude': 30.4609, 'longitude': -97.79467}
# 3   {'latitude': 30.470254940882956, 'longitude': ...
# 4   {'latitude': 30.46724938131647, 'longitude': -...
# 5   {'latitude': 30.448741292198, 'longitude': -97...
# 6   {'latitude': 30.4016022028548, 'longitude': -9...
# 7   {'latitude': 30.40301526685455, 'longitude': -...
# 8       {'latitude': 30.2999, 'longitude': -97.74031}
# 9   {'latitude': 30.382055738338, 'longitude': -97...
# 10  {'latitude': 30.36106951490272, 'longitude': -...
# 11     {'latitude': 30.43327, 'longitude': -97.77172}
# 12        {'latitude': 30.31067, 'longitude': -97.74}
# 13  {'latitude': 30.4180224748019, 'longitude': -9...
# 14     {'latitude': 30.41815, 'longitude': -97.70212}
# 15  {'latitude': 30.372020678526145, 'longitude': ...
# 16     {'latitude': 30.33075, 'longitude': -97.74021}
# 17   {'latitude': 30.357255, 'longitude': -97.715117}
# 18  {'latitude': 30.365026831635483, 'longitude': ...
# 19  {'latitude': 30.337163276287555, 'longitude': ...
#
#                                   transactions price  \
# 0   [restaurant_reservation, delivery, pickup]    $$
# 1                           [delivery, pickup]    $$
# 2                           [delivery, pickup]    $$
# 3                                   [delivery]   $$$
# 4                                           []   $$$
# 5                           [delivery, pickup]    $$
# 6                           [delivery, pickup]    $$
# 7                                   [delivery]    $$
# 8                                           []   NaN
# 9                                   [delivery]     $
# 10                                  [delivery]    $$
# 11                          [delivery, pickup]    $$
# 12                                  [delivery]  $$$$
# 13                                  [delivery]    $$
# 14                          [delivery, pickup]    $$
# 15                                  [delivery]    $$
# 16                          [delivery, pickup]    $$
# 17                                          []   NaN
# 18                          [delivery, pickup]    $$
# 19                          [delivery, pickup]    $$
#
#                                              location         phone  \
# 0   {'address1': '13376 N Hwy 183', 'address2': 'S...  +15122435554
# 1   {'address1': '8557 Research Blvd', 'address2':...  +15123946967
# 2   {'address1': '13776 US N 183 Hwy', 'address2':...  +15128140130
# 3   {'address1': '11066 Pecan Park Blvd', 'address...  +15122570788
# 4   {'address1': '13201 Ranch Rd 620 N', 'address2...  +15128529288
# 5   {'address1': '13435 N Hwy 183', 'address2': 'S...  +15122571411
# 6   {'address1': '11601 Rock Rose Ave', 'address2'...  +15123945550
# 7   {'address1': '3120 Palm Way', 'address2': 'Ste...  +15126151070
# 8   {'address1': '3208 Guadalupe St', 'address2': ...
# 9   {'address1': '11220 N Lamar Blvd', 'address2':...  +15128377800
# 10  {'address1': '9200 N Lamar St', 'address2': 'S...  +15128213388
# 11  {'address1': '8650 Spicewood Springs Rd', 'add...  +15123368889
# 12  {'address1': '4200 N Lamar Blvd', 'address2': ...  +15129164808
# 13  {'address1': '2501 W Parmer Ln', 'address2': '...  +15128349304
# 14  {'address1': '2501 W Parmer Ln', 'address2': '...  +15125995372
# 15  {'address1': '9070 Research Blvd', 'address2':...  +15127701100
# 16  {'address1': '5520 Burnet Rd', 'address2': 'St...  +15123304439
# 17  {'address1': '8339 Research Blvd', 'address2':...  +15123586994
# 18  {'address1': '3808 Spicewood Springs Rd', 'add...  +15128529990
# 19  {'address1': '6929 Airport Blvd', 'address2': ...  +15123584101
#
#      display_phone      distance
# 0   (512) 243-5554  10164.580464
# 1   (512) 394-6967   2622.217752
# 2   (512) 814-0130  11162.411396
# 3   (512) 257-0788  12981.508374
# 4   (512) 852-9288  12323.535970
# 5   (512) 257-1411  10375.594861
# 6   (512) 394-5550   2293.890341
# 7   (512) 615-1070   2393.672206
# 8                    9809.832919
# 9   (512) 837-7800   2136.405899
# 10  (512) 821-3388   2768.490591
# 11  (512) 336-8889   7965.333796
# 12  (512) 916-4808   8669.283179
# 13  (512) 834-9304   3834.795248
# 14  (512) 599-5372   3754.641661
# 15  (512) 770-1100   2163.271494
# 16  (512) 330-4439   6613.343657
# 17  (512) 358-6994   3041.311715
# 18  (512) 852-9990   4331.885826
# 19  (512) 358-4101   5265.195135

# %%
## How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 7

# %%
for i in tqdm_notebook(range(1,n_pages+1)):
    ## The block of code we want to TRY to run
    try:
        
        time.sleep(.2)
        
        ## Read in results in progress file and check the length
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
        
        ## save number of results for to use as offset
        n_results = len(previous_results)
        
        
        ## use n_results as the OFFSET 
        results = yelp.search_query(location = location, term = term,
                                   offset = n_results+1)

        ## append new results and save to file
        previous_results.extend(results['businesses'])
        
        with open(JSON_FILE, 'w') as f:
            json.dump(previous_results, f)

            
    ## What to do if we get an error/exception.
    except Exception as e:
        print(' [!] ERROR', e)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]

# %% [markdown]
# ## Open the Final JSON File with Pandas

# %%
df = pd.read_json(JSON_FILE)
display(df.head(), df.tail())
# Out:
#                        id                            alias  \
# 0  wMgWB_27X6Wl-K1mHokAtw  ichi-umi-sushi-and-ramen-austin
# 1  qDyZQ6mT1JajQ7_Yj7PeLw    jinya-ramen-bar-austin-austin
# 2  -jxEILUSqsWL0Oo7cQDfVg               sazan-ramen-austin
# 3  t_DIHeRee3f7mlDwDT15pA          ramen-del-barrio-austin
# 4  NplrGF_5kZx5K67CgxqaKg            marufuku-ramen-austin
#
#                        name  \
# 0    Ichi-Umi Sushi & Ramen
# 1  JINYA Ramen Bar - Austin
# 2               Sazan Ramen
# 3          Ramen Del Barrio
# 4           Marufuku Ramen
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/ElJ4yn...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/egvu0A...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/VyeiBC...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/eq5GTp...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/1toY9I...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/ichi-umi-sushi-and-ra...          1143
# 1  https://www.yelp.com/biz/jinya-ramen-bar-austi...          1023
# 2  https://www.yelp.com/biz/sazan-ramen-austin?ad...           338
# 3  https://www.yelp.com/biz/ramen-del-barrio-aust...            32
# 4  https://www.yelp.com/biz/marufuku-ramen-austin...           192
#
#                                           categories  rating  \
# 0  [{'alias': 'ramen', 'title': 'Ramen'}, {'alias...     4.0
# 1             [{'alias': 'ramen', 'title': 'Ramen'}]     3.5
# 2             [{'alias': 'ramen', 'title': 'Ramen'}]     4.5
# 3             [{'alias': 'ramen', 'title': 'Ramen'}]     4.5
# 4  [{'alias': 'ramen', 'title': 'Ramen'}, {'alias...     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 30.354756, 'longitude': -97.73306...  [pickup, delivery]
# 1  {'latitude': 30.4002508252956, 'longitude': -9...  [pickup, delivery]
# 2  {'latitude': 30.3366386489722, 'longitude': -9...  [pickup, delivery]
# 3  {'latitude': 30.4128494714331, 'longitude': -9...                  []
# 4   {'latitude': 30.298142, 'longitude': -97.705115}  [pickup, delivery]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '2525 W Anderson Ln', 'address2':...  +15124079000
# 1    $$  {'address1': '3210 Esperanza Xing', 'address2'...  +15128297779
# 2    $$  {'address1': '6929 Airport Blvd', 'address2': ...  +15124325474
# 3   NaN  {'address1': '1700 W Parmer Ln', 'address2': '...
# 4    $$  {'address1': '1900 Aldrich St', 'address2': 'S...  +15125035003
#
#     display_phone     distance
# 0  (512) 407-9000  3963.021564
# 1  (512) 829-7779  2219.124387
# 2  (512) 432-5474  5323.162663
# 3                  3884.163741
# 4  (512) 503-5003  9514.619689
#                          id                    alias      name  \
# 116  rfBrlGnqKECoTWyXRyV5GA       7-eleven-austin-48  7-Eleven
# 117  RljWH0uq5MuJPLdaLXBLDw  7-eleven-pflugerville-3  7-Eleven
# 118  a1sdhCOIfwMMWhSMiRwsGQ       7-eleven-austin-42  7-Eleven
# 119  EHJme7HnwXdQsmcR2FpevQ       7-eleven-austin-45  7-Eleven
# 120  m0GAVukZsyzh5OJ_NwSOYA       7-eleven-austin-30  7-Eleven
#
#                                              image_url  is_closed  \
# 116  https://s3-media2.fl.yelpcdn.com/bphoto/VsgSxk...      False
# 117  https://s3-media3.fl.yelpcdn.com/bphoto/R-wQsn...      False
# 118  https://s3-media2.fl.yelpcdn.com/bphoto/Swq0JM...      False
# 119  https://s3-media2.fl.yelpcdn.com/bphoto/58dYOZ...      False
# 120  https://s3-media4.fl.yelpcdn.com/bphoto/DIDY6i...      False
#
#                                                    url  review_count  \
# 116  https://www.yelp.com/biz/7-eleven-austin-48?ad...            13
# 117  https://www.yelp.com/biz/7-eleven-pflugerville...             9
# 118  https://www.yelp.com/biz/7-eleven-austin-42?ad...             6
# 119  https://www.yelp.com/biz/7-eleven-austin-45?ad...             6
# 120  https://www.yelp.com/biz/7-eleven-austin-30?ad...            15
#
#                                             categories  rating  \
# 116  [{'alias': 'convenience', 'title': 'Convenienc...     2.0
# 117  [{'alias': 'convenience', 'title': 'Convenienc...     1.0
# 118  [{'alias': 'convenience', 'title': 'Convenienc...     2.0
# 119  [{'alias': 'servicestations', 'title': 'Gas St...     1.5
# 120  [{'alias': 'servicestations', 'title': 'Gas St...     3.5
#
#                                            coordinates        transactions  \
# 116  {'latitude': 30.4612942, 'longitude': -97.7926...  [pickup, delivery]
# 117  {'latitude': 30.4552299, 'longitude': -97.664909}  [pickup, delivery]
# 118  {'latitude': 30.3541330333074, 'longitude': -9...  [pickup, delivery]
# 119  {'latitude': 30.4238364298384, 'longitude': -9...  [pickup, delivery]
# 120  {'latitude': 30.4043511, 'longitude': -97.6384...  [pickup, delivery]
#
#     price                                           location         phone  \
# 116     $  {'address1': '10207 Lake Creek Pkwy', 'address...  +15122509724
# 117     $  {'address1': '15829 Ih 35', 'address2': None, ...  +15122527904
# 118     $  {'address1': '3550 Far West Blvd', 'address2':...  +15127950018
# 119     $  {'address1': '3801 W Parmer Ln', 'address2': '...  +15128730175
# 120     $  {'address1': '1624 E Howard Ln', 'address2': '...  +15122522786
#
#       display_phone      distance
# 116  (512) 250-9724  11706.426905
# 117  (512) 252-7904   8996.165751
# 118  (512) 795-0018   5363.011903
# 119  (512) 873-0175   4431.621300
# 120  (512) 252-2786   7188.742249

# %%
# check for duplicate results
df.duplicated(subset='id').sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             121 non-null    object
#  1   alias          121 non-null    object
#  2   name           121 non-null    object
#  3   image_url      121 non-null    object
#  4   is_closed      121 non-null    bool
#  5   url            121 non-null    object
#  6   review_count   121 non-null    int64
#  7   categories     121 non-null    object
#  8   rating         121 non-null    float64
#  9   coordinates    121 non-null    object
#  10  transactions   121 non-null    object
#  11  price          106 non-null    object
#  12  location       121 non-null    object
#  13  phone          121 non-null    object
#  14  display_phone  121 non-null    object
#  15  distance       121 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 14.4+ KB

# %%
## convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/Austin-ramen.csv.gz'

# %%
## Save it as a compressed csv (to save space)
df.to_csv(csv_file, compression = 'gzip', index = False)

# %%
# save the final results to a compressed csv
df.to_csv('Data/final_results_TX_ramen.csv.gz', compression='gzip',index=False)
